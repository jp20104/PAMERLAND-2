# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.20.4' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'vanilla'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]


if colabconfig["server_version"] < "1.17":
    #en la segunda linea de este if puedes cambiar la version de java que quieres instalar, (openjdk-𝟠-jre- (En el 8 puedes cambiarlo si lo necesitas dependiendo del error que te salga))
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-8-jre-headless &>/dev/null') and print("OpenJDK 8 installed") or print("Failed to install OpenJDK 8.")
# Instalar OpenJDK 17 si la version de Minecraft es 1.17 o superior
else:
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-17-jre-headless &>/dev/null') and print("OpenJDK 17 installed") or print("Failed to install OpenJDK 17.")

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dSnjz7Gtg5XT6Aa3aQJnBaKiuq_7SxLoHBsVWkRM7oyAdEyv" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui
    
    
elif tunnel_service == "zerotier":
    # Instalar ZeroTier
    # !curl -s https://install.zerotier.com | sudo bash

    # Ingresar a tu red de ZeroTier
    zerotier_network_id = "YOUR_NETWORK_ID"  # Remplaza con tu id de red de ZeroTier
    # !sudo zerotier-cli join $zerotier_network_id

    # Esperar a que ZeroTier se una a la red
    import time
    time.sleep(120)  # Aumentalo si es neceasrio

    #Chequea el estado de ZeroTier
    # !sudo zerotier-cli status


print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	ops.json	   vanilla.jar	   world
# banned-players.json  libraries	server.properties  versions
# colabconfig.json     logs	usercache.json	   whitelist.json
# Failed to install OpenJDK 17.
# Reading package lists...Usando ngrok
#
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   ca-certificates-java java-common libpcsclite1
# Suggested packages:
#   default-jre pcscd libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java java-common libpcsclite1 openjdk-17-jre-headless
# 0 upgraded, 4 newly installed, 0 to remove and 30 not upgraded.
# Need to get 43.7 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 4.tcp.ngrok.io:12045
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Starting net.minecraft.server.Main
# [18:58:23] [ServerMain/INFO]: Environment: Environment[sessionHost=https://sessionserver.mojang.com, servicesHost=https://api.minecraftservices.com, name=PROD]
# [18:58:25] [ServerMain/INFO]: Loaded 7 recipes
# [18:58:25] [ServerMain/INFO]: Loaded 1271 advancements
# [18:58:25] [Server thread/INFO]: Starting minecraft server version 1.20.4
# [18:58:25] [Server thread/INFO]: Loading properties
# [18:58:25] [Server thread/INFO]: Default game type: SURVIVAL
# [18:58:25] [Server thread/INFO]: Generating keypair
# [18:58:26] [Server thread/INFO]: Starting Minecraft server on *:25565
# [18:58:26] [Server thread/INFO]: Using epoll channel type
# [18:58:26] [Server thread/WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [18:58:26] [Server thread/WARN]: The server will make no attempt to authenticate usernames. Beware.
# [18:58:26] [Server thread/WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [18:58:26] [Server thread/WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [18:58:26] [Server thread/INFO]: Preparing level "world"
# [18:58:28] [Server thread/INFO]: Preparing start region for dimension minecraft:overworld
# [18:58:32] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-1/INFO]: Preparing spawn area: 0%
# [18:58:32] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [18:58:33] [Worker-Main-2/INFO]: Preparing spawn area: 0%
# [18:58:33] [Worker-Main-3/INFO]: Preparing spawn area: 0%
# [18:58:34] [Worker-Main-2/INFO]: Preparing spawn area: 15%
# [18:58:34] [Server thread/INFO]: Time elapsed: 5945 ms
# [18:58:34] [Server thread/INFO]: Done (8.510s)! For help, type "help"
# [18:58:59] [Server thread/INFO]: Ricardo20104[/[0:0:0:0:0:0:0:1%0]:59480] logged in with entity id 76 at (1609.9783333726202, 69.0, -12223.428831606629)
# [18:58:59] [Server thread/INFO]: Ricardo20104 joined the game
# [18:59:34] [Server thread/INFO]: jurandir97[/[0:0:0:0:0:0:0:1%0]:42764] logged in with entity id 453 at (1515.00697238381, 68.0, -12272.69828863744)
# [18:59:34] [Server thread/INFO]: jurandir97 joined the game
# [19:00:38] [Server thread/INFO]: [Not Secure] <Ricardo20104> chupapinga
# [19:00:41] [Server thread/INFO]: [Not Secure] <Ricardo20104> entra a discorrd
# [19:01:15] [Server thread/INFO]: [Not Secure] <jurandir97> no
# [19:02:34] [Server thread/INFO]: [Not Secure] <jurandir97> prendi, un cigarrillo
# [19:02:46] [Server thread/INFO]: [Not Secure] <jurandir97> y llore tanto como si, fuera un niño
# [19:02:57] [Server thread/INFO]: [Not Secure] <jurandir97> y una triste expresion, solo queda en mi
# [19:03:04] [Server thread/INFO]: [Not Secure] <jurandir97> q buena cancin csmr
# [19:03:06] [Server thread/INFO]: Thom[/[0:0:0:0:0:0:0:1%0]:45224] logged in with entity id 1075 at (1494.4928849995042, 78.0, -12236.050933172792)
# [19:03:06] [Server thread/INFO]: Thom joined the game
# [19:03:14] [Server thread/INFO]: [Not Secure] <Thom> alo?
# [19:03:24] [Server thread/INFO]: [Not Secure] <Thom> entra al discord oe cabrU
# [19:03:28] [Server thread/INFO]: [Not Secure] <jurandir97> no cmtr
# [19:03:33] [Server thread/INFO]: [Not Secure] <Thom> xq
# [19:03:41] [Server thread/INFO]: [Not Secure] <jurandir97> disfruta el silencio
# [19:06:13] [Server thread/INFO]: [Not Secure] <Thom> que tienes mi amor¿?
# [19:06:27] [Server thread/INFO]: [Not Secure] <jurandir97> un dias de mrd
# [19:06:41] [Server thread/INFO]: [Not Secure] <Thom> y un beso te ayudaria?
# [19:06:47] [Server thread/INFO]: [Not Secure] <jurandir97> presencial
# [19:06:54] [Server thread/INFO]: [Not Secure] <jurandir97> x a la distancia no
# [19:07:00] [Server thread/INFO]: [Not Secure] <Thom> JAJAJAJAJA CTMRE
# [19:07:04] [Server thread/INFO]: [Not Secure] <Thom> T.T
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [19:11:19] [Server thread/INFO]: [Not Secure] <Thom> JA9
# [19:11:22] [Server thread/INFO]: [Not Secure] <Thom> COMO VA SER
# [19:11:25] [Server thread/INFO]: [Not Secure] <jurandir97> q
# [19:11:26] [Server thread/INFO]: [Not Secure] <Thom> ARRIBA
# [19:11:31] [Server thread/INFO]: [Not Secure] <Thom> Y ABAJO QUE IRAN?
# [19:11:38] [Server thread/INFO]: [Not Secure] <jurandir97> nose
# [19:11:41] [Server thread/INFO]: [Not Secure] <Thom> LA CSM
# [19:11:43] [Server thread/INFO]: [Not Secure] <jurandir97> lo q pida ricardo
# [19:11:57] [Server thread/INFO]: [Not Secure] <jurandir97> arriba es el cine y la sala de juegos
# [19:12:16] [Server thread/INFO]: [Not Secure] <jurandir97> desahuevate ctrm
# [19:12:23] [Server thread/INFO]: [Not Secure] <jurandir97> no me vallas a empujar
# [19:13:31] [Server thread/INFO]: [Not Secure] <Thom> TOMA
# [19:13:46] [Server thread/INFO]: [Not Secure] <jurandir97> estos son abetos
# [19:13:53] [Server thread/INFO]: [Not Secure] <Thom> a
# [19:14:07] [Server thread/INFO]: [Not Secure] <Thom> no es roble oscuro
# [19:14:08] [Server thread/INFO]: [Not Secure] <Thom> diablo
# [19:14:12] [Server thread/INFO]: [Not Secure] <jurandir97> mejor pienso en otra cosa
# [19:15:18] [Server thread/INFO]: [Not Secure] <Thom> pasa pidra
# [19:15:26] [Server thread/INFO]: [Not Secure] <jurandir97> en el cofre hay
# [19:15:35] [Server thread/INFO]: [Not Secure] <jurandir97> el de arriba
# [19:16:44] [Server thread/INFO]: [Not Secure] <Thom> ven perra
# [19:16:51] [Server thread/INFO]: [Not Secure] <jurandir97> pa donde
# [19:16:51] [Server thread/INFO]: [Not Secure] <Thom> lo sigo?
# [19:17:04] [Server thread/INFO]: [Not Secure] <jurandir97> sigue la linea
# [19:17:07] [Server thread/INFO]: [Not Secure] <Ricardo20104> oe jurandir de mrd
# [19:17:13] [Server thread/INFO]: [Not Secure] <jurandir97> q
# [19:17:16] [Server thread/INFO]: [Not Secure] <Ricardo20104> entra al discord p mamapinga
# [19:17:23] [Server thread/INFO]: [Not Secure] <jurandir97> no pinga
# [19:17:41] [Server thread/INFO]: [Not Secure] <jurandir97> ahora se ve mas decente
# [19:17:58] [Server thread/INFO]: [Not Secure] <jurandir97> antony
# [19:18:04] [Server thread/INFO]: [Not Secure] <Thom> eu
# [19:18:05] [Server thread/INFO]: [Not Secure] <jurandir97> aca van a ser los acensores
# [19:18:08] [Server thread/INFO]: [Not Secure] <jurandir97> mira
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [19:18:29] [Server thread/INFO]: [Not Secure] <jurandir97> uno q valla al 2do
# [19:18:37] [Server thread/INFO]: [Not Secure] <jurandir97> y otro q valla al 3ero
# [19:19:06] [Server thread/INFO]: [Not Secure] <Thom> de gua
# [19:19:08] [Server thread/INFO]: [Not Secure] <Thom> agua?
# [19:20:29] [Server thread/INFO]: [Not Secure] <jurandir97> si
# [19:21:40] [Server thread/INFO]: [Ricardo20104: Set the weather to rain & thunder]
# [19:21:49] [Server thread/INFO]: [Ricardo20104: Set the weather to clear]
# [19:26:06] [Server thread/INFO]: [Not Secure] <Thom> ctm
# [19:26:10] [Server thread/INFO]: [Not Secure] <jurandir97> tarado
# [19:26:16] [Server thread/WARN]: Thom moved wrongly!
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [19:30:08] [Server thread/INFO]: [Not Secure] <jurandir97> la clara kchera
# [19:30:17] [Server thread/INFO]: [Not Secure] <Ricardo20104> la abuela chupapinga
# [19:30:22] [Server thread/INFO]: [Not Secure] <Thom> rika las 2
# [19:30:23] [Server thread/INFO]: [Not Secure] <Thom> mmm
# [19:30:29] [Server thread/INFO]: [Not Secure] <Ricardo20104> le meto el andador por el culote que tiene
# [19:30:32] [Server thread/INFO]: [Not Secure] <Ricardo20104> la marlona
# [19:35:37] [Server thread/INFO]: [Not Secure] <Thom> xq las cosas redondas se guardan en cosas cuadradas?
# [19:36:56] [Server thread/INFO]: [Not Secure] <jurandir97> piensa bien lo q vas a hacer
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [19:38:19] [Server thread/INFO]: [Not Secure] <Ricardo20104> juri muy monotono esta piedra
# [19:38:24] [Server thread/INFO]: [Not Secure] <Ricardo20104> los ladrillos
# [19:38:30] [Server thread/INFO]: [Not Secure] <jurandir97> q propones
# [19:38:30] [Server thread/INFO]: [Not Secure] <Ricardo20104> debe tener algo que lo rompa
# [19:38:50] [Server thread/INFO]: [Not Secure] <Ricardo20104> la blackstone
# [19:38:54] [Server thread/INFO]: [Not Secure] <jurandir97> xd
# [19:38:58] [Server thread/INFO]: [Not Secure] <jurandir97> otra cosa
# [19:40:07] [Server thread/INFO]: [Not Secure] <jurandir97> la marlene
# [19:40:11] [Server thread/INFO]: [Not Secure] <jurandir97> encima de mis bolas
# [19:40:31] [Server thread/INFO]: [Not Secure] <Thom> amor y paz
# [19:40:37] [Server thread/INFO]: [Not Secure] <Thom> mentira
# [19:40:53] [Server thread/INFO]: [Not Secure] <jurandir97> a tu madre le voy a hacer el amor y a tu culo no le voy a dar paz
# [19:41:03] [Server thread/INFO]: [Not Secure] <Thom> causa
# [19:41:04] [Server thread/INFO]: [Not Secure] <Thom> las papas
# [19:41:12] [Server thread/INFO]: [Not Secure] <Thom> xq las saca
# [19:43:43] [Server thread/INFO]: [Not Secure] <jurandir97> esa vagoneta va mas lenta q tramite del gobierno
# [19:43:52] [Server thread/INFO]: [Not Secure] <Thom> metele semen p
# [19:44:01] [Server thread/INFO]: [Not Secure] <jurandir97> osea
# [19:44:09] [Server thread/INFO]: [Not Secure] <jurandir97> pa ti es mas practico
# [19:44:17] [Server thread/INFO]: [Not Secure] <jurandir97> que se rodee toda la vuelta
# [19:44:24] [Server thread/INFO]: [Not Secure] <jurandir97> en vez de cortar camino
# [19:44:31] [Server thread/INFO]: [Not Secure] <jurandir97> imbecil de mrd
# [19:44:31] [Server thread/INFO]: [Not Secure] <Thom> has lo p
# [19:47:34] [Server thread/INFO]: [Not Secure] <Thom> oe
# [19:47:41] [Server thread/INFO]: [Not Secure] <Thom> e l t e c h o ?
# [19:47:51] [Server thread/INFO]: [Not Secure] <Thom> q a l t u r a?
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [19:49:02] [Server thread/INFO]: [Not Secure] <jurandir97> voy a ierme 20 minutos
# [19:49:07] [Server thread/INFO]: [Not Secure] <jurandir97> van a seguir?
# [19:49:42] [Server thread/INFO]: jurandir97 lost connection: Disconnected
# [19:49:42] [Server thread/INFO]: jurandir97 left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:10:31] [Server thread/INFO]: jurandir97[/[0:0:0:0:0:0:0:1%0]:55774] logged in with entity id 16470 at (1539.699999988079, 57.0, -12233.963048800173)
# [20:10:31] [Server thread/INFO]: jurandir97 joined the game
# [20:10:53] [Server thread/INFO]: [Not Secure] <jurandir97> hola
# [20:10:58] [Server thread/INFO]: [Not Secure] <Thom> hola
# [20:11:00] [Server thread/INFO]: [Not Secure] <jurandir97> y tu como te llamas?
# [20:11:22] [Server thread/INFO]: [Not Secure] <Thom> habra 3 piso?
# [20:11:26] [Server thread/INFO]: [Not Secure] <jurandir97> si
# [20:11:32] [Server thread/INFO]: [Not Secure] <Thom> que esperas
# [20:11:38] [Server thread/INFO]: [Not Secure] <jurandir97> pera p mrd
# [20:13:56] [Server thread/INFO]: [Not Secure] <Thom> ya vuelvo
# [20:13:58] [Server thread/INFO]: Thom lost connection: Disconnected
# [20:13:58] [Server thread/INFO]: Thom left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:20:50] [Server thread/INFO]: [Not Secure] <jurandir97> duerme
# [20:23:49] [Server thread/INFO]: [Not Secure] <Ricardo20104> A MIMIR
# [20:23:59] [Server thread/INFO]: [Not Secure] <jurandir97> cuando quieres nomas
# [20:24:32] [Server thread/INFO]: Thom[/[0:0:0:0:0:0:0:1%0]:35082] logged in with entity id 18736 at (1514.434110074157, 61.0, -12218.930958028126)
# [20:24:32] [Server thread/INFO]: Thom joined the game
# [20:24:44] [Server thread/INFO]: [Ricardo20104: Set own game mode to Spectator Mode]
# [20:26:48] [Server thread/INFO]: Thom lost connection: Disconnected
# [20:26:48] [Server thread/INFO]: Thom left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:37:19] [Server thread/INFO]: Thom[/[0:0:0:0:0:0:0:1%0]:33258] logged in with entity id 21441 at (1515.2723788121514, 61.0, -12230.36551077879)
# [20:37:19] [Server thread/INFO]: Thom joined the game
# [20:37:22] [Server thread/INFO]: [Not Secure] <Thom> hola
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:41:15] [Server thread/INFO]: [Not Secure] <jurandir97> la puta q te pario
# [20:41:17] [Server thread/INFO]: [Not Secure] <Thom> ups
# [20:41:21] [Server thread/INFO]: [Not Secure] <Thom> xd
# [20:41:30] [Server thread/INFO]: [Not Secure] <Thom> q haces?
# [20:41:37] [Server thread/INFO]: [Not Secure] <jurandir97> kachaadome a tu vieja
# [20:41:41] [Server thread/INFO]: [Not Secure] <Thom> un clasico
# [20:41:43] [Server thread/INFO]: [Not Secure] <Thom> habla
# [20:41:47] [Server thread/INFO]: [Not Secure] <jurandir97> de todos los dias
# [20:41:51] [Server thread/INFO]: [Not Secure] <jurandir97> el techo p webon
# [20:42:00] [Server thread/INFO]: [Not Secure] <jurandir97> el cortapiedras
# [20:42:37] [Server thread/INFO]: [Not Secure] <Thom> t ayiudo
# [20:42:45] [Server thread/INFO]: [Not Secure] <Thom> aqui esta ven
# [20:42:45] [Server thread/INFO]: [Not Secure] <jurandir97> haz vidrio
# [20:43:33] [Server thread/INFO]: [Not Secure] <Thom> ese conchasumare ta roncando
# [20:43:35] [Server thread/INFO]: [Not Secure] <Thom> xD
# [20:43:35] [Server thread/INFO]: [Not Secure] <jurandir97> el vidrio
# [20:46:34] [Server thread/INFO]: [Not Secure] <Thom> que le falta al techo?
# [20:47:59] [Server thread/INFO]: [Not Secure] <jurandir97> vidrio
# [20:48:03] [Server thread/INFO]: [Not Secure] <Thom> ariba
# [20:48:09] [Server thread/INFO]: [Not Secure] <jurandir97> vidrio p
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [20:49:15] [Server thread/INFO]: [Not Secure] <Thom> ya estan todos los aldeanos
# [20:49:19] [Server thread/INFO]: [Not Secure] <jurandir97> no
# [20:49:22] [Server thread/INFO]: [Not Secure] <Thom> si
# [20:49:25] [Server thread/INFO]: [Not Secure] <jurandir97> falta el 3er piso
# [20:49:28] [Server thread/INFO]: [Not Secure] <Thom> :_:
# [20:49:41] [Server thread/INFO]: [Not Secure] <jurandir97> no te quejes
# [20:49:48] [Server thread/INFO]: [Not Secure] <jurandir97> faltan 4 pisos hacia abajo
# [20:50:46] [Server thread/INFO]: [Not Secure] <Thom> xDDDDDD
# [20:50:51] [Server thread/INFO]: [Not Secure] <Thom> LOS HARAN UTDS CSM
# [20:51:00] [Server thread/INFO]: [Not Secure] <Thom> CUCHAO
# [20:51:01] [Server thread/INFO]: [Not Secure] <jurandir97> causa
# [20:51:09] [Server thread/INFO]: [Not Secure] <jurandir97> me cago en tus muertos
# [20:51:14] [Server thread/INFO]: [Not Secure] <Thom> YA ESPAÑOL
# [20:51:19] [Server thread/INFO]: jurandir97 was slain by Thom using [Gabu]
# [20:51:23] [Server thread/INFO]: [Not Secure] <Thom> DIABLO
# [20:51:33] [Server thread/INFO]: [Not Secure] <Thom> T
# [20:51:48] [Server thread/INFO]: [Not Secure] <jurandir97> cuida tu casa nomas
# [20:51:54] [Server thread/INFO]: [Not Secure] <Thom> JAJAJA que lloron
# [20:52:06] [Server thread/INFO]: [Not Secure] <jurandir97> cuida todo lo q sea tuyo
# [20:52:11] [Server thread/INFO]: [Not Secure] <Thom> jajajajaja
# [20:52:25] [Server thread/INFO]: [Not Secure] <Thom> me perdonas?
# [20:53:20] [Server thread/INFO]: [Not Secure] <Thom> oe donde cierra el techo?
# [20:53:30] [Server thread/INFO]: [Not Secure] <jurandir97> el vidrio primero
# [20:53:32] [Server thread/INFO]: [Not Secure] <Thom> esos 3 no mas?
# [20:53:37] [Server thread/INFO]: [Not Secure] <Thom> por eso
# [20:53:38] [Server thread/INFO]: [Not Secure] <jurandir97> 3q?
# [20:53:44] [Server thread/INFO]: [Not Secure] <Thom> el vidrio va encima o en el 3ero
# [20:53:49] [Server thread/INFO]: [Not Secure] <jurandir97> si
# [20:53:53] [Server thread/INFO]: [Not Secure] <Thom> si q
# [20:54:04] [Server thread/INFO]: [Not Secure] <jurandir97> mano
# [20:54:09] [Server thread/INFO]: [Not Secure] <jurandir97> solo trae el vidrio
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:02:02] [Server thread/INFO]: [Not Secure] <Thom> cristiano o messi=?
# [21:02:49] [Server thread/INFO]: Ricardo20104 lost connection: Disconnected
# [21:02:49] [Server thread/INFO]: Ricardo20104 left the game
# [21:02:56] [Server thread/INFO]: [Not Secure] <Thom> ya me jalo mu chamo , mas tarde vuelvo
# [21:02:57] [Server thread/INFO]: Thom lost connection: Disconnected
# [21:02:57] [Server thread/INFO]: Thom left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [21:44:03] [Server thread/INFO]: Ricardo20104[/[0:0:0:0:0:0:0:1%0]:38922] logged in with entity id 32637 at (1505.0719313854117, 68.85769547183185, -12249.732781575764)
# [21:44:03] [Server thread/INFO]: Ricardo20104 joined the game
# [21:44:46] [Server thread/INFO]: Ricardo20104 lost connection: Disconnected
# [21:44:46] [Server thread/INFO]: Ricardo20104 left the game
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
